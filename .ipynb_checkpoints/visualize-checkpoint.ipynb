# %%
import numpy as np
import numpy.random
import matplotlib.pyplot as plt
import pandas

# %matplotlib inline

# %%
def plot_imgs(full_data):
    
    for i in range(0, len(full_data)):
        plt.subplot(10,10,i)
        
        frame = plt.gca()
        frame.get_xaxis().set_visible(False)
        frame.get_yaxis().set_visible(False)
        heatmap = plt.pcolor(full_data[i], cmap = 'gist_gray')#cmap ='RdBu')#cmap=plt.cm.Blues)



#    plt.show()


f = open("weight_dump.txt", "r")

content = [x.strip('\n') for x in f.readlines()]

# temp_content = [x.strip() for x in f.readlines()]
# temp_content = [x.strip("\n") for x in f.readlines()]
    
# count = 0

# while count < len(temp_content):
#     if temp_content[count] == "":
#         del temp_content[count]
#         count = count - 1
        
#     count += 1
    
    
//print "here", content[1], "hi"
    
full_data = []
for line in content:

    line_split = line.split(" ")
    del line_split[len(line_split)-1]
    
    linear_data = []
    
    for val in line_split:
        linear_data.append(float(val))
    
    data = []
    for i in range(0, 28):
        new_list = []
        data.append(new_list)
        for j in range(0,28):
            data[i].append( linear_data[ i * 28 + j] )
         
    numpy_data = np.array(data)
    full_data.append(numpy_data)
    
print len(full_data)
plot_imgs(np.array(full_data))
# Out:
# here -0.02163316652 -0.2596025809 -0.258209768 -0.07026970705 -0.1092181953 -0.1114748445 -0.4347979737 -0.3915853101 -0.2506015435 0.01266717109 -0.257684123 -0.1749794006 -0.3995329741 -0.1338329371 -0.3319866806 -0.1561602005 -0.1896559585 -0.2199583812 -0.353654453 -0.06252430003 -0.05882939994 0.06707652736 -0.1743751976 -0.07164915665 -0.0576032173 -0.06250138588 -0.022320823 -0.4080591049 -0.1151375889 -0.06307931943 -0.4714575041 -0.2160470539 -0.3938457151 -0.2874345252 -0.2351602385 -0.246726397 0.02092759832 0.2586909664 0.1334970459 0.2476574927 -0.1616132461 -0.3622021881 -0.1205686116 -0.1293834087 -0.203296197 -0.4214401516 0.08117736229 -0.3169137061 -0.1644248594 -0.05982062295 -0.3669132868 -0.03865802166 -0.359279537 -0.1007562048 -0.1539605762 -0.4064587125 -0.0886564428 -0.2325412584 -0.2416320202 -0.03052703857 -0.4277811784 -0.4577584502 -0.1075426223 -0.1245111506 -0.01924281577 0.5970616753 0.7713169627 0.0949765813 -0.5783291808 -0.6028966018 -0.3662203064 -0.730535484 -0.5246676372 -0.6818671515 -0.4237403538 -0.657790267 -0.36542551 -0.1345918868 -0.076049887 -0.128584072 -0.03317609147 -0.3041616309 0.1010244667 -0.09450504427 -0.333746972 -0.252406755 -0.1037945271 -0.2093345484 -0.2839587148 -0.4052638846 -0.02472778403 0.2152416041 0.5050206907 0.9676098939 0.941753159 -0.302882129 -1.508558748 -1.53425051 -1.230375696 -0.9740285888 -0.7850124524 -0.7559933184 -0.617746999 -0.5686756731 